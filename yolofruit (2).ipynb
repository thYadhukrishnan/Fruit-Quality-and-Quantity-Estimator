# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15067, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 15067 (delta 68), reused 82 (delta 54), pack-reused 14961
# Receiving objects: 100% (15067/15067), 13.65 MiB | 24.52 MiB/s, done.
# Resolving deltas: 100% (10410/10410), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 7.0 MB/s
#      |████████████████████████████████| 41 kB 501 kB/s
#      |████████████████████████████████| 138 kB 5.4 MB/s
#      |████████████████████████████████| 145 kB 50.1 MB/s
#      |████████████████████████████████| 54 kB 2.8 MB/s
#      |████████████████████████████████| 67 kB 5.5 MB/s
#      |████████████████████████████████| 178 kB 15.4 MB/s
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...
# Setup complete. Using torch 1.12.1+cu113 (Tesla T4)

# %%
# !unzip -q ../make1.zip -d ../

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/make1"

# %%
# !python train.py --img 416 --batch 32 --epochs 50 --data cust.yaml --weights yolov5l.pt --cache
# Out:
# train: weights=yolov5l.pt, cfg=, data=cust.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --data cust.yaml --weights runs/train/exp3/weights/best.pt --img 416 --conf 0.1
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=data/images, data=cust.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-196-ge42c89d Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46140588 parameters, 0 gradients, 107.7 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 416x320 (no detections), 32.4ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 256x416 1 goodapple, 1 goodguava, 21.6ms
# Speed: 0.3ms pre-process, 27.0ms inference, 0.7ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source ../Image_78.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../Image_78.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-198-gacff977 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46140588 parameters, 0 gradients, 107.7 GFLOPs
# image 1/1 /content/Image_78.jpg: 416x416 10 goodapples, 1 fruitbox, 30.5ms
# Speed: 0.5ms pre-process, 30.5ms inference, 1.5ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp4

# %%
# !python val.py --data cust.yaml --weights runs/train/exp/weights/best.pt
# Out:
# val: data=/content/yolov5/data/cust.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46140588 parameters, 0 gradients, 107.7 GFLOPs
# val: Scanning '/content/drive/MyDrive/make1/labels/val.cache' images and labels... 628 found, 1 missing, 0 empty, 0 corrupt: 100% 629/629 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:24<00:00,  1.20s/it]
#                    all        629       1147      0.803      0.787      0.856      0.665
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/make1/images/val --weights '/content/drive/MyDrive/yolo/best.pt' --img 416 --conf 0.5 --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/yolo/best.pt'], source=/content/drive/MyDrive/make1/images/val, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-246-ge40662f Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46140588 parameters, 0 gradients, 107.7 GFLOPs
# image 1/629 /content/drive/MyDrive/make1/images/val/20190809_155758.jpg: 416x416 1 goodapple, 30.6ms
# image 2/629 /content/drive/MyDrive/make1/images/val/20190809_155801.jpg: 416x416 1 goodapple, 30.6ms
# image 3/629 /content/drive/MyDrive/make1/images/val/20190809_155821.jpg: 416x416 1 goodapple, 30.6ms
# ...

# %%
# !zip new1.zip /content/yolov5/runs/detect/exp2
# Out:
#   adding: content/yolov5/runs/detect/exp2/ (stored 0%)

# %%
# !zip -r /content/sample_data.zip /content/yolov5/runs/detect/exp2
# Out:
#   adding: content/yolov5/runs/detect/exp2/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp2/Image_9.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_20190822_080337.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/IMG_20190822_080257_1.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/20190813_125803.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/IMG_1995.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/Image_12.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp2/20190809_160523.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp2/Image_4.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/20190809_161246.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/IMG_20190910_172254.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/20190813_121728.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp2/20190813_121711.jpg (deflated 4%)
# ...

# %%
# !apt-get install git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
# !git config --global user.email "yadhukrishnanth@gmail.com"
# !git config --global user.name "thYadhukrishnan"
# !git config --global credential.helper store

# %%
# !git clone https://github.com/thYadhukrishnan/Fruit-Quality-and-Quantity-Estimator.git
# Out:
# Cloning into 'Fruit-Quality-and-Quantity-Estimator'...
# ...

# %%
cd /content/Fruit-Quality-and-Quantity-Estimator
# Out:
# /content/Fruit-Quality-and-Quantity-Estimator

# %%
# !git add .

# %%
# !git commit -m "Quality Estimator"
# Out:
# On branch master
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git push origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/thYadhukrishnan/Fruit-Quality-and-Quantity-Estimator.git'
